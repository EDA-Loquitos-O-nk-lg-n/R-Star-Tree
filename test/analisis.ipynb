# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# # Insercion

# %%
T_I = pd.read_csv("T_I.csv")
T_I.head()
# Out:
#         1       2       3        4        5        6        7        8  \
# 0  481500  485500  661600   110500   450400   508300   387000   676700
# 1  168800  562900  494100  1018800   367600  1433100  1413900   211600
# 2  341100  300600  885300   250400  1013200   597100   652800   809600
# 3  185600  314000  462300   196300   863200   815500    32200   655300
# 4  277900  632300  620700  1490800   562100   704400   246400  1067200
#
#         9       10  ...     491     492     493      494      495      496  \
# 0  435000   300500  ...  816900  428600  624200  2045200   778700  1405700
# 1  579700   688500  ...  116700  269900  237100   685400   415000   731300
# 2  520100   464700  ...  135400  314500  314700   469800   603200   509800
# 3  697600   942100  ...  233300  779600  500600   788700   559000   335800
# 4  696300  1074100  ...  712400  290400  695500   170700  1028100   419100
#
#       497      498     499     500
# 0  500200  1157600  385300  265600
# ...

# %%
plt.plot(range(1, T_I.shape[1]+1), T_I.mean())
