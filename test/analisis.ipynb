# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Insercion

# %%
df_insercion = pd.read_csv("T_I.csv")
df_insercion.head()
# Out:
#        1       2        3       4        5        6        7        8       9  \
# 0  23600  528200  1607100  443200  1222600    25500   444300   882600  845500
# 1  15700  926000   428800  976000    81400  1067100   850900  1264400  465200
# 2  15200  919000   432000  418500  1247300    37400   441600  1648100  427900
# 3  16600  894700   940000  474200   930100   927100    29200  1417700  520800
# 4  16700  911200   461500  933000   931800    27500  1866400    33300  496400
#
#         10  ...      491      492      493      494      495     496      497  \
# 0   797600  ...   955600  1369300   927900  1327400   897100  499400   553100
# 1   441500  ...    83300   136400   884800   883900   956400  861100  1691300
# 2  1306700  ...   113000    84500   539900   934500  1115400  105600   582300
# 3   991800  ...   529000  2370700    91800   550200  1029400  616100   992900
# 4   509400  ...  1079300    87100  1341100   931000   586900  479400   513900
#
#        498      499     500
# ...

# %%
plt.plot(range(1, 501), df_insercion.mean())
plt.title("Tiempo medio de inserción (ns) para insertar conjuntos de 10 objetos en Arbol-R-Estrella")
plt.xlabel("Conjunto C insertado")
plt.ylabel("Tiempo de inserción (ns)")
# Out:
# Text(0, 0.5, 'Tiempo de inserción (ns)')

# %% [markdown]
# # Eliminación
